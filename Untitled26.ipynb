# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhargavpolla/hand-written-math-solver/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPool2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras.applications import ResNet50V2 as ResNet
from tensorflow.keras.callbacks import EarlyStopping,  ReduceLROnPlateau
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

import cv2
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 28)

import random
import os
import imutils
from imutils.contours import sort_contours

# %%
def extractImages(datadir):
    imagesData = []
    imagesLabel = []
    for folder in os.listdir(datadir):
        path = os.path.join(datadir, folder)
        for images in os.listdir(path):
            img = cv2.imread(os.path.join(path, images), cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (32, 32))
            imagesData.append(img)
            imagesLabel.append(folder)
    combined = list(zip(imagesData, imagesLabel))
    random.shuffle(combined)
    imagesData, imagesLabel = zip(*combined)

    return (imagesData, imagesLabel)

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/data.zip
# !unzip -qo data.zip
# Out:
# --2025-07-01 18:28:51--  https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/data.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.158.95, 3.5.212.225, 16.12.40.55, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.158.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28437489 (27M) [application/x-zip-compressed]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]  27.12M  4.45MB/s    in 15s
#
# 2025-07-01 18:29:07 (1.84 MB/s) - ‘data.zip’ saved [28437489/28437489]

# %%
imagesData = []
imagesLabel = []
train_data_dir = 'data/dataset'

imagesData, imagesLabel = extractImages(train_data_dir)

print("number of image: ",len(imagesData))
print("shape of image:  ",imagesData[1].shape)
print("labels:          ",list(set(imagesLabel)))
# Out:
# number of image:  7600
# shape of image:   (32, 32)
# labels:           ['8', '7', 'mul', '4', '9', '1', '0', '5', '6', 'sub', 'div', '2', '3', 'add']

# %%
imagesTrainData, imagesTestData, imagesTrainLabel, imagesTestLabel = train_test_split(
                                                                                    imagesData,imagesLabel,
                                                                                    shuffle=True,
                                                                                    test_size=0.2,
                                                                                    random_state=42,
                                                                                    stratify= imagesLabel )

# %%
def showImage (images,label,part):
    figure = plt.figure(figsize=((len(part)/10 + 1)*10, (len(part)/10 + 1)*2))
    j = 0
    for i in part:
        lbl = label[i]
        img = images[i]
        img = cv2.resize(img, (256, 256))
        figure.add_subplot(int(len(part)/10)+1, 10, j+1)
        plt.imshow(img,cmap='gray')
        plt.axis('off')
        plt.title(lbl)
        j += 1

# %%
showImage(imagesTrainData,imagesTrainLabel, range(20))

# %%
unique_idx = [imagesTrainLabel.index(i) for i in list(set(imagesTrainLabel))]
showImage(imagesTrainData,imagesTrainLabel, unique_idx )

# %%
sns.countplot(x= list(imagesTrainLabel));

# %%
label_encoder = LabelEncoder()
Y_train = label_encoder.fit_transform(imagesTrainLabel)
Y_test = label_encoder.transform(imagesTestLabel)

# %%
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

# %%
X_train = np.array(imagesTrainData)
X_test = np.array(imagesTestData)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
X_train = X_train/255.
X_test = X_test/255.

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6080, 32, 32, 1)
# (1520, 32, 32, 1)
# (6080, 14)
# (1520, 14)

# %%
X_train[0].shape
# Out:
# (32, 32, 1)

# %%
def facial_recognition_detect_mood(input_shape=(32, 32, 1)):


    model = Sequential()

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(14, activation='softmax'))

    model.compile(optimizer=Adam(lr=0.0001,),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
def facial_recognition_detect_mood(input_shape=(32, 32, 1)):


    model = Sequential()

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(14, activation='softmax'))

    # Use learning_rate instead of lr
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = facial_recognition_detect_mood()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     8,389,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 14)             │        14,350 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,441,934 (32.20 MB)
#  Trainable params: 8,441,614 (32.20 MB)
#  Non-trainable params: 320 (1.25 KB)

# %%
def step_decay(epoch):
    initial_learning_rate = 0.001
    dropEvery = 10
    factor = 0.5
    lr = initial_learning_rate*(factor**np.floor((1 + epoch)/dropEvery))
    return float(lr)

checkpoint = ModelCheckpoint('HandwrittenMathEquationModel.keras',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='min')

earlyStopping = EarlyStopping(monitor='val_accuracy',
                              mode='auto',
                              verbose=1,
                              patience=10,
                              restore_best_weights=True)

reduceLr = ReduceLROnPlateau(monitor='val_accuracy',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

callbacks = [checkpoint,earlyStopping,reduceLr, LearningRateScheduler(step_decay)]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Assuming you want basic image augmentation
aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

hist = model.fit(aug.flow(X_train, Y_train, batch_size=64),
                 batch_size=64,
                 epochs=90,
                 validation_data=(X_test, Y_test),
                 callbacks=callbacks)
# Out:
# Epoch 1/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8073 - loss: 0.6642
# Epoch 1: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.8071 - loss: 0.6649 - val_accuracy: 0.8947 - val_loss: 0.3986 - learning_rate: 0.0010
# Epoch 2/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7613 - loss: 0.8320
# Epoch 2: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.7614 - loss: 0.8321 - val_accuracy: 0.5092 - val_loss: 1.5930 - learning_rate: 0.0010
# Epoch 3/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.7679 - loss: 0.9009
# Epoch 3: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.7679 - loss: 0.9006 - val_accuracy: 0.4776 - val_loss: 2.2593 - learning_rate: 0.0010
# Epoch 4/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7852 - loss: 0.8242
# Epoch 4: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 416ms/step - accuracy: 0.7851 - loss: 0.8241 - val_accuracy: 0.3743 - val_loss: 4.0806 - learning_rate: 0.0010
# Epoch 5/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.7902 - loss: 0.8032
# Epoch 5: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.7902 - loss: 0.8031 - val_accuracy: 0.3283 - val_loss: 7.1856 - learning_rate: 0.0010
# Epoch 6/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7947 - loss: 0.7578
# Epoch 6: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 43s 450ms/step - accuracy: 0.7947 - loss: 0.7579 - val_accuracy: 0.2513 - val_loss: 9.5379 - learning_rate: 0.0010
# Epoch 7/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8043 - loss: 0.7468
# Epoch 7: val_accuracy did not improve from 0.10000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 443ms/step - accuracy: 0.8042 - loss: 0.7468 - val_accuracy: 0.6388 - val_loss: 2.5954 - learning_rate: 2.0000e-04
# Epoch 8/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8054 - loss: 0.7369
# Epoch 8: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 441ms/step - accuracy: 0.8055 - loss: 0.7370 - val_accuracy: 0.2967 - val_loss: 8.4501 - learning_rate: 0.0010
# Epoch 9/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8222 - loss: 0.6942
# Epoch 9: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.8222 - loss: 0.6943 - val_accuracy: 0.4421 - val_loss: 4.2479 - learning_rate: 0.0010
# Epoch 10/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8266 - loss: 0.6757
# Epoch 10: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.8267 - loss: 0.6754 - val_accuracy: 0.9276 - val_loss: 0.3889 - learning_rate: 5.0000e-04
# Epoch 11/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8435 - loss: 0.5986
# Epoch 11: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.8435 - loss: 0.5986 - val_accuracy: 0.8605 - val_loss: 0.5665 - learning_rate: 5.0000e-04
# Epoch 12/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.8497 - loss: 0.5791
# Epoch 12: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 422ms/step - accuracy: 0.8497 - loss: 0.5790 - val_accuracy: 0.8053 - val_loss: 0.6959 - learning_rate: 5.0000e-04
# Epoch 13/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8633 - loss: 0.5277
# Epoch 13: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.8632 - loss: 0.5278 - val_accuracy: 0.7296 - val_loss: 1.4255 - learning_rate: 5.0000e-04
# Epoch 14/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8723 - loss: 0.5230
# Epoch 14: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.8722 - loss: 0.5231 - val_accuracy: 0.6961 - val_loss: 3.1471 - learning_rate: 5.0000e-04
# Epoch 15/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8552 - loss: 0.5481
# Epoch 15: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.8552 - loss: 0.5479 - val_accuracy: 0.5691 - val_loss: 2.1325 - learning_rate: 5.0000e-04
# Epoch 16/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8680 - loss: 0.5315
# Epoch 16: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.8680 - loss: 0.5314 - val_accuracy: 0.9474 - val_loss: 0.2763 - learning_rate: 5.0000e-04
# Epoch 17/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8660 - loss: 0.5025
# Epoch 17: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 439ms/step - accuracy: 0.8660 - loss: 0.5025 - val_accuracy: 0.8079 - val_loss: 1.0015 - learning_rate: 5.0000e-04
# Epoch 18/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8617 - loss: 0.5400
# Epoch 18: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.8618 - loss: 0.5397 - val_accuracy: 0.9303 - val_loss: 0.3036 - learning_rate: 5.0000e-04
# Epoch 19/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8710 - loss: 0.4801
# Epoch 19: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 39s 412ms/step - accuracy: 0.8710 - loss: 0.4801 - val_accuracy: 0.8921 - val_loss: 0.4604 - learning_rate: 5.0000e-04
# Epoch 20/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8790 - loss: 0.4581
# Epoch 20: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 39s 414ms/step - accuracy: 0.8790 - loss: 0.4582 - val_accuracy: 0.9599 - val_loss: 0.2014 - learning_rate: 2.5000e-04
# Epoch 21/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8805 - loss: 0.4378
# Epoch 21: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 422ms/step - accuracy: 0.8806 - loss: 0.4378 - val_accuracy: 0.9638 - val_loss: 0.1862 - learning_rate: 2.5000e-04
# Epoch 22/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8901 - loss: 0.4269
# Epoch 22: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.8901 - loss: 0.4270 - val_accuracy: 0.8868 - val_loss: 0.5938 - learning_rate: 2.5000e-04
# Epoch 23/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.8866 - loss: 0.4168
# Epoch 23: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 39s 412ms/step - accuracy: 0.8865 - loss: 0.4170 - val_accuracy: 0.9289 - val_loss: 0.2990 - learning_rate: 2.5000e-04
# Epoch 24/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8971 - loss: 0.4129
# Epoch 24: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.8971 - loss: 0.4129 - val_accuracy: 0.5842 - val_loss: 3.0392 - learning_rate: 2.5000e-04
# Epoch 25/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8868 - loss: 0.4172
# Epoch 25: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.8868 - loss: 0.4170 - val_accuracy: 0.8566 - val_loss: 0.5615 - learning_rate: 2.5000e-04
# Epoch 26/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8932 - loss: 0.4106
# Epoch 26: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.8932 - loss: 0.4104 - val_accuracy: 0.9678 - val_loss: 0.1935 - learning_rate: 2.5000e-04
# Epoch 27/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9002 - loss: 0.3909
# Epoch 27: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 39s 415ms/step - accuracy: 0.9002 - loss: 0.3909 - val_accuracy: 0.9612 - val_loss: 0.1945 - learning_rate: 2.5000e-04
# Epoch 28/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8905 - loss: 0.4046
# Epoch 28: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 43s 432ms/step - accuracy: 0.8906 - loss: 0.4046 - val_accuracy: 0.7822 - val_loss: 0.8412 - learning_rate: 2.5000e-04
# Epoch 29/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9008 - loss: 0.3822
# Epoch 29: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.9008 - loss: 0.3823 - val_accuracy: 0.9526 - val_loss: 0.2202 - learning_rate: 2.5000e-04
# Epoch 30/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8903 - loss: 0.4003
# Epoch 30: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 419ms/step - accuracy: 0.8904 - loss: 0.4002 - val_accuracy: 0.9743 - val_loss: 0.1532 - learning_rate: 1.2500e-04
# Epoch 31/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9015 - loss: 0.3620
# Epoch 31: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 426ms/step - accuracy: 0.9016 - loss: 0.3621 - val_accuracy: 0.9671 - val_loss: 0.1687 - learning_rate: 1.2500e-04
# Epoch 32/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.8999 - loss: 0.3622
# Epoch 32: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.9000 - loss: 0.3622 - val_accuracy: 0.9783 - val_loss: 0.1414 - learning_rate: 1.2500e-04
# Epoch 33/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9160 - loss: 0.3491
# Epoch 33: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 431ms/step - accuracy: 0.9159 - loss: 0.3492 - val_accuracy: 0.9191 - val_loss: 0.3585 - learning_rate: 1.2500e-04
# Epoch 34/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8933 - loss: 0.3772
# Epoch 34: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.8934 - loss: 0.3771 - val_accuracy: 0.9645 - val_loss: 0.1684 - learning_rate: 1.2500e-04
# Epoch 35/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9053 - loss: 0.3613
# Epoch 35: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 418ms/step - accuracy: 0.9053 - loss: 0.3613 - val_accuracy: 0.9671 - val_loss: 0.1604 - learning_rate: 1.2500e-04
# Epoch 36/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9109 - loss: 0.3336
# Epoch 36: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 428ms/step - accuracy: 0.9110 - loss: 0.3335 - val_accuracy: 0.9697 - val_loss: 0.1587 - learning_rate: 1.2500e-04
# Epoch 37/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9148 - loss: 0.3262
# Epoch 37: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - accuracy: 0.9148 - loss: 0.3263 - val_accuracy: 0.9783 - val_loss: 0.1342 - learning_rate: 1.2500e-04
# Epoch 38/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9043 - loss: 0.3330
# Epoch 38: val_accuracy did not improve from 0.10000
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.5000001187436283e-05.
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 48s 502ms/step - accuracy: 0.9043 - loss: 0.3332 - val_accuracy: 0.9164 - val_loss: 0.3546 - learning_rate: 2.5000e-05
# Epoch 39/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9131 - loss: 0.3482
# Epoch 39: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 75s 429ms/step - accuracy: 0.9131 - loss: 0.3481 - val_accuracy: 0.9586 - val_loss: 0.1954 - learning_rate: 1.2500e-04
# Epoch 40/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9048 - loss: 0.3502
# Epoch 40: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 433ms/step - accuracy: 0.9048 - loss: 0.3502 - val_accuracy: 0.9822 - val_loss: 0.1276 - learning_rate: 6.2500e-05
# Epoch 41/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9205 - loss: 0.3095
# Epoch 41: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 437ms/step - accuracy: 0.9205 - loss: 0.3096 - val_accuracy: 0.9822 - val_loss: 0.1293 - learning_rate: 6.2500e-05
# Epoch 42/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9120 - loss: 0.3333
# Epoch 42: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 444ms/step - accuracy: 0.9120 - loss: 0.3333 - val_accuracy: 0.9691 - val_loss: 0.1591 - learning_rate: 6.2500e-05
# Epoch 43/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9254 - loss: 0.3034
# Epoch 43: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 438ms/step - accuracy: 0.9253 - loss: 0.3035 - val_accuracy: 0.9855 - val_loss: 0.1162 - learning_rate: 6.2500e-05
# Epoch 44/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9152 - loss: 0.3272
# Epoch 44: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 434ms/step - accuracy: 0.9151 - loss: 0.3272 - val_accuracy: 0.9651 - val_loss: 0.1643 - learning_rate: 6.2500e-05
# Epoch 45/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9090 - loss: 0.3434
# Epoch 45: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.9091 - loss: 0.3432 - val_accuracy: 0.9836 - val_loss: 0.1202 - learning_rate: 6.2500e-05
# Epoch 46/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9213 - loss: 0.3092
# Epoch 46: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 438ms/step - accuracy: 0.9212 - loss: 0.3093 - val_accuracy: 0.9750 - val_loss: 0.1402 - learning_rate: 6.2500e-05
# Epoch 47/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9205 - loss: 0.3249
# Epoch 47: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.9205 - loss: 0.3248 - val_accuracy: 0.9730 - val_loss: 0.1402 - learning_rate: 6.2500e-05
# Epoch 48/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9172 - loss: 0.3035
# Epoch 48: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.9172 - loss: 0.3035 - val_accuracy: 0.9763 - val_loss: 0.1302 - learning_rate: 6.2500e-05
# Epoch 49/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9213 - loss: 0.3011
# Epoch 49: val_accuracy did not improve from 0.10000
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.2500000593718141e-05.
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 432ms/step - accuracy: 0.9213 - loss: 0.3011 - val_accuracy: 0.9803 - val_loss: 0.1196 - learning_rate: 1.2500e-05
# Epoch 50/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9207 - loss: 0.2957
# Epoch 50: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 435ms/step - accuracy: 0.9206 - loss: 0.2958 - val_accuracy: 0.9717 - val_loss: 0.1442 - learning_rate: 3.1250e-05
# Epoch 51/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9200 - loss: 0.3002
# Epoch 51: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.9200 - loss: 0.3002 - val_accuracy: 0.9776 - val_loss: 0.1215 - learning_rate: 3.1250e-05
# Epoch 52/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9217 - loss: 0.2954
# Epoch 52: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 49s 521ms/step - accuracy: 0.9217 - loss: 0.2956 - val_accuracy: 0.9822 - val_loss: 0.1121 - learning_rate: 3.1250e-05
# Epoch 53/90
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9187 - loss: 0.3034
# Epoch 53: val_accuracy did not improve from 0.10000
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.9187 - loss: 0.3033 - val_accuracy: 0.9822 - val_loss: 0.1204 - learning_rate: 3.1250e-05
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 43.

# %%
import os
from google.colab import files
print( os.getcwd() )
files.download( "HandwrittenMathEquationModel.h5" )
# Out:
# /content
